# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
from selenium.webdriver.common.by import By

# %%
#launch url
url = "https://crautos.com/autosusados/searchresults.cfm"

# create a new Firefox session
driver = webdriver.Firefox()
driver.implicitly_wait(30)
driver.get(url)

# %%
soup_level1=BeautifulSoup(driver.page_source, 'lxml')
soup_level1.find_all('a',class_='margin-bottom-10')

#for link in soup_level1.find_all('a', id=re.compile("^MainContent_uxLevel2_JobTitles_uxJobTitleBtn_")):  

python_button = driver.find_element(By.CLASS_NAME , value='margin-bottom-10')
python_button.click

#python_button.click() #click link

#re.compile("^MainContent_uxLevel2_JobTitles_uxJobTitleBtn_")
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="bc1aea41-7d62-4976-beee-a1b9f09c576a", element="9c6c8ef1-7de9-4139-a103-eba6a3cf1992")>>

# %%
#soup_level1.find_all('a',class_='margin-bottom-10')
driver.execute_script("javascript:p('80')")
soup=driver.page_source

# %%
soup
# Out:
# '<html lang="en"><head>\n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\n<meta name="description" content="">\n<meta name="author" content="">\n<link rel="shortcut icon" href="/favicon.ico">\n\n<title>crautos.com - Autos Usados Costa Rica</title>\n<!-- Bootstrap core CSS -->\n<link href="https://crautos.com/bt/css/bootstrap.min.css" rel="stylesheet">\n<link href="https://crautos.com/bt/css/styledark.css" rel="stylesheet">\n\n<script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-VSKP37KZJC&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js"></script><script src="https://connect.facebook.net/signals/config/396561437623716?v=2.9.133&amp;r=stable&amp;domain=crautos.com" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript">\n<!--\nfunction p(p1)\n{\n   document.Form1.p.value = p1;\n   document.Form1.submit();\n}\n\nvar popUpWin=0;\nfunction s() {\n  var left;\n\tleft = parseInt(window.screen.width / 2) - 240;\n\tvar top;\n\ttop = parseInt(window.screen.height / 2) - 300;\nwindow.name=\'thisparent\';\n\n  if(popUpWin)\n  {\n    if(!popUpWin.closed) popUpWin.close();\n  }\n  popUpWin = open(\'/rmicrautos/mlogin.cfm\',\'\',\'toolbar=no,directories=no,status=no,menubar=no,scrollbars=no,resizable=no,width=480,height=550,left=\'+left+\', top=\'+top+\' \');\n\n}\n\nfunction lo() {\nwindow.name=\'thisparent\';\n  if(popUpWin)\n  {\n    if(!popUpWin.closed) popUpWin.close();\n  }\n  popUpWin = open(\'../rmicrautos/mlogout.cfm\',\'\',\'width=1,height=1\');\n}\n\n//-->\n</script>\n<style type="text/css">\n<!--\n.marqueefont {\n\tfont-size: 13px;\n\tfont-weight: 400;\n\tfont-family: Oxygen;\n\tcolor: #555555;\n\tline-height: 13px;\n}\n.header-image {\n\tbackground-size: cover;\n}\n.price-xs {\n\tfont-family: Oxygen;\n\tfont-size: 14px;\n\tfont-weight: 600;\n\tcolor: #007700;\n}\n.pricedollars-xs {\n\tfont-family: Oxygen;\n\tfont-size: 12px;\n\tfont-weight: 600;\n\tcolor: #000;\n}\n\n.pricedollars {\n\tfont-family: Oxygen;\n\tfont-size: 16px;\n\tfont-weight: 600;\n\tcolor: #000000;\n}\n.pricedollarslg {\n\tfont-family: Oxygen;\n\tfont-size: 22px;\n\tfont-weight: 600;\n\tcolor: #000000;\n}\n.pricechuzoweek {\n\tfont-size: 12px;\n\tfont-weight: 600;\n\tcolor: #000000;\n\tline-height: 14px;\n}\n\n.orprice {\n\tfont-size: 12px;\n\tfont-weight: 600;\n\tcolor: #880000;\n\ttext-decoration: line-through;\n}\n.dealprice {\n\tfont-size: 13px;\n\tfont-weight: 600;\n\tcolor: #008800;\n}\n.ofertas {\n\tfont-family: Oxygen;\n\tfont-size: 14px;\n\tfont-weight: 600;\n\tcolor: #000088;\n\tline-height: 13px;\n\tmargin-top: 20px;\n}\n.othercars {\n\tborder: 1px solid #e5e5e5;\n\t-moz-border-radius: 11px / 13px;\n\t-webkit-border-radius: 11px / 13px;\n\tborder-radius: 11px / 13px;\n\t-moz-background-clip: padding;\n\t-webkit-background-clip: padding-box;\n\tbackground-clip: padding-box;\n\tbackground-color: #efefef;\n\t-moz-box-shadow: 0 0 5px rgba(0,0,0,.13);\n\t-webkit-box-shadow: 0 0 5px rgba(0,0,0,.13);\n\tbox-shadow: 0 0 5px rgba(0,0,0,.13);\n\tmargin-bottom: 20px;\n\tfont-family: Oxygen;\n\tpadding-left: 0px;\n\tpadding-right: 0px;\n\tpadding-top: 10px;\n\tpadding-bottom: 0px;\n}\n.othercars:hover {\n\tbackground-image: -moz-linear-gradient(bottom, #dedede 0%, #f9f9f9 50%);\n\tbackground-image: -o-linear-gradient(bottom, #dedede 0%, #f9f9f9 50%);\n\tbackground-image: -webkit-linear-gradient(bottom, #dedede 0%, #f9f9f9 50%);\n\tbackground-image: linear-gradient(bottom, #dedede 0%, #f9f9f9 50%);\n}\n.font1 {\n\tfont-family: Oxygen;\n\tfont-style: normal;\n\tcolor: #000000;\n\tfont-size: 14px;\n\tline-height: 16px;\n\ttext-decoration: none;\n}\nA.font1:link {\n\tcolor: #0;\n\ttext-decoration: none;\ ...

# %%
# abre la pagina de busqueda
base_url = 'https://crautos.com/autosusados/searchresults.cfm'  
respuesta = requests.get(base_url)
soup = BeautifulSoup(respuesta.content,'html.parser')

# %%
anuncio = anuncios[0]
anuncio.find_all('td')

# %%
params = {'p': 1, 'c': 10020}  
  
# Send a GET request to the URL with the query parameters  
response = requests.get(base_url, params=params)  
  
# Create a BeautifulSoup object with the HTML content of the page  
soup = BeautifulSoup(response.content, 'html.parser')  
  
# Find the total number of pages to scrape  
total_pages = int(soup.find('span', class_='pagecount').text.split()[0])

# %%
# Loop through all the pages and scrape the data  
results = []  
for page in range(1, total_pages+1):  
    # Set the query parameters for the current page  
    params['p'] = page  
      
    # Send a GET request to the URL with the updated query parameters  
    response = requests.get(base_url, params=params)  
      
    # Create a BeautifulSoup object with the HTML content of the page  
    soup = BeautifulSoup(response.content, 'html.parser')  
      
    # Find all the listings on the page  
    listings = soup.find_all('div', class_='listing')  
      
    # Extract the data from each listing  
    for listing in listings:  
        title = listing.find('h2', class_='title').text  
        price = listing.find('div', class_='price').text  
        year = listing.find('div', class_='year').text  
        mileage = listing.find('div', class_='mileage').text  
          
        # Store the data in a dictionary  
        data = {  
            'title': title.strip(),  
            'price': price.strip(),  
            'year': year.strip(),  
            'mileage': mileage.strip()  
        }  
          
        # Append the data to the results list  
        results.append(data)  
  
# Print the results  
for result in results:  
    print(result)
